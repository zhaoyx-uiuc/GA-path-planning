# %% [markdown]
# plot evolution of fitness (length)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import statistics
mpl.rcParams['font.family'] = 'Times New Roman'  # Choose a font family (e.g., 'serif', 'sans-serif', etc.)
mpl.rcParams['font.size'] = 12  # Set the default font size
mpl.rcParams['font.weight'] = 'normal'  # Set the font weight ('normal', 'bold', 'light', etc.)
mpl.rcParams['axes.labelweight'] = 'normal'  # Set the label font weight
mpl.rcParams['axes.titlesize'] = 14  # Set the title font size

generation=500
sub_list=[]
fitness_list=[]
std_list=[]
minfitness_list=[]
label_list=[]
path_list=[]
ruleinit_list=[]
population_list=[125, 250, 500]
tournament_list=[0.05, 0.1, 0.2]
mutation_list=[0.05,0.1,0.2]
rule_list=[0, 0.5, 1]
new_list=[0,0.1,0.2]
coverage_list=[ 0.9, 0.95, 0.99]
individual_list=[0.5, 0.75, 1]

#path_list=['test_samets/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/0.1_0_0.75_0.1_0.9/','test_samets/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/0.1_0_0.75_0.1_0.95/','test_samets/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=500_gen=1000/0.05_0_0.5_0.1_0.99/',]
label_list=population_list
for label in label_list:
    #path_list.append('test_samets/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/0.1_0_0.75_0.1_'+str(label)+'/') #coverage
    #path_list.append('test3/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/0.1_0_0.75_'+str(label)+'_0.95/') #tournament_size
    #path_list.append('test3/ruleinit='+str(label)+'_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/0.1_0_0.75_0.1_0.95/') #rule_list
    path_list.append('test_samets/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind='+str(label)+'_gen=1000/0.1_0_0.75_0.1_0.95/') #population
path_counter=0
all_data_list=[]
for path in path_list:
    
    data_list=[]
    data_minfit_list=[]
    for idx in range(10):

        filepath=path+str(idx+1)+'/fitness.txt'
        data=np.loadtxt(filepath)
        for itemidx in range(data.shape[0]):
            if data[itemidx]>100000:
                data[itemidx]=None
        data_list.append(data[0:generation])
        data_minfit_list.append(np.nanmin(data[0:generation]))
    path_counter+=1
    #np.savetxt('min'+str(path_counter)+'.txt',data_minfit_list)
    minfitness_list.append(data_minfit_list)
    data_array=np.asarray(data_list)
    all_data_list.append(data_list)


    data_avg=np.mean(data_array[0:generation], axis=0)
    data_std=np.std(data_array[0:generation], axis=0)
    #print(np.nanmin(data_avg[0:generation]))

    fitness_list.append(data_avg[0:generation])
    std_list.append(data_std[0:generation])
for item in minfitness_list:
    avg_min_length=sum(item) / len(item)
    std_deviation= statistics.stdev(item)
    print(avg_min_length)
    print(std_deviation)
#for i in range(len(label_list)):
 #   label_list[i] = label_list[i].replace('FOV=120_dist=10_', '')

# Example data
x = np.linspace(1,fitness_list[0].shape[0],fitness_list[0].shape[0])
fig, ax = plt.subplots(dpi=400.0)

# Plot the data on the axis object
#label_list=['0.9', '0.95', '0.99']
for idx in range(len(label_list)):
    ax.plot(x, fitness_list[idx], label='avg - '+str(label_list[idx]))
for idx in range(len(label_list)):
    ax.fill_between(x, fitness_list[idx] - std_list[idx], fitness_list[idx] + std_list[idx], alpha=0.2, label='std range - '+str(label_list[idx]))


# Add labels to the x and y axes
ax.set_xlabel('generation')
ax.set_ylabel('path length')
ax.text(180, 430, 'population', fontsize=12)
plt.ylim(80, 500)

labels=ax.get_label()
ax.legend()
plt.savefig('population.tiff', dpi=400, format='tiff')
#plt.ylim(100, 650)
# Show the plot
#plt.show()
# Out:
# 184.57437744140626
# 18.793403400035544
# 144.6217010498047
# 5.757087190111019
# 144.14645233154297
# 14.30849476675409
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %% [markdown]
# plot the visibility of model changing with timestep

# %%
import numpy as np
from utils import calculate_coverage, output_visualizable_faces
import matplotlib.pyplot as plt
import torch
data_path='safedist=0.5_visdist=10_step=1/'
VIS_MAT=np.loadtxt(data_path+'filtered_vis_matrix')
DIR_MAT=np.load(data_path+'filtered_dir_matrix.npy')
AREA_ARR=np.loadtxt(data_path+'filtered_area_matrix')#.reshape((VIS_MAT.shape[0],1))

VIS_MAT_tensor=torch.tensor(VIS_MAT, dtype=torch.float32)
DIR_MAT_tensor=torch.tensor(DIR_MAT, dtype=torch.float32)
AREA_ARR_tensor=torch.tensor(AREA_ARR, dtype=torch.float32)
VIS_MAT_tensor = VIS_MAT_tensor.to('cuda')
DIR_MAT_tensor = DIR_MAT_tensor.to('cuda')
AREA_ARR_tensor = AREA_ARR_tensor.to('cuda')

xmin,xmax,ymin,ymax,zmin,zmax,step=-23,0,-13,8,1,11,1
lin_parameters=(xmin,xmax,ymin,ymax,zmin,zmax,step)
FOV_THRES=np.pi/2
FOV_COS_THRES=np.cos(FOV_THRES)
results_path='test3/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/'
subfolder_path='0.1_0_0.75_0.1_0.95/1/'
path=np.load(results_path+subfolder_path+'test_path.npy')
positions=path[0,:,:]

vis_list=[]
coverage_list=[]
max_coverage=1.0
single_viewpoint_coverage_list=[]
vis_arr_count=np.zeros((VIS_MAT.shape[0],))
vis_mat_count=np.zeros((VIS_MAT.shape[0],positions.shape[0]))



for idx in range(positions.shape[0]):
    positions_local=positions[0:idx+1,:]
    #sights_local=sights[0:idx+1,:]

    positions_local_tensor = torch.tensor(positions_local, dtype=torch.float32)
    positions_local_tensor = positions_local_tensor.to('cuda')
    #sights_local_tensor = torch.tensor(sights_local, dtype=torch.float32)
    #sights_local_tensor = sights_local_tensor.to('cuda')

    coverage,vis_arr=calculate_coverage( positions_local_tensor,None,VIS_MAT_tensor,DIR_MAT_tensor,lin_parameters,AREA_ARR_tensor,FOV_COS_THRES)

    positions_single_tensor = torch.tensor(positions_local[idx,:].reshape((1,3)), dtype=torch.float32)
    positions_single_tensor = positions_single_tensor .to('cuda')
    #sights_single_tensor = torch.tensor(sights_local[idx,:].reshape((1,3)), dtype=torch.float32)
    #sights_single_tensor = sights_single_tensor.to('cuda')

    single_viewpoint_coverage, single_viewpoint_vis_arr=calculate_coverage(positions_single_tensor,None,VIS_MAT_tensor,DIR_MAT_tensor,lin_parameters,AREA_ARR_tensor,FOV_COS_THRES)
    #vis_arr_count+=single_viewpoint_vis_arr
    #vis_mat_count[:,idx]=vis_arr_count
    vis_list.append(vis_arr)
    coverage_list.append(coverage.item()/max_coverage)
    single_viewpoint_coverage_list.append(single_viewpoint_coverage.item()/max_coverage)
    #print(coverage)
coverage_step_list=[coverage_list[0]]
for idx in range(len(coverage_list)-1):
    coverage_step_list.append(coverage_list[idx+1]-coverage_list[idx])

print(len(coverage_list))
#print(vis_arr_count)
def plot_list(data):
    # Create x-axis values from 0 to n-1, where n is the length of the data list
    length=len(data)
    x = range(length)
    
    # Plot the data
    plt.plot(x, data)
    
    # Add labels and title
    plt.xlabel('viewpoint index on path')
    plt.ylabel('coverage')
    #plt.title('Accumulated coverage')
    plt.ylim(0, 1)
    plt.gcf().set_dpi(300)
    
    # Save the plot to a TIFF file
    plt.savefig('Accumulated coverage.tiff', format='tiff', dpi=300)
    # Display the plot
    plt.show()

def plot_bar(data):
    length=len(data)
    x = range(length)  # x-axis values
    
    # Plot the bar chart
    plt.bar(x, data, width = 1.0)

    # Add labels and title
    plt.xlabel('viewpoints')
    plt.ylabel('added coverage')
    plt.title('new coverage for each viewpoint')
    # Display the plot
    plt.show()
def plot_bar2(data):
    length=len(data)
    x = range(length)  # x-axis values

    # Plot the bar chart
    plt.bar(x, data, width = 1.0)

    # Add labels and title
    plt.xlabel('viewpoints')
    plt.ylabel('single viewpoint coverage')
    plt.title('coverage for each viewpoint')

    # Display the plot
    plt.show()
def plot_dual_bar(list1, list2):
    x = np.arange(len(list1))  # x-axis values

    width = 1.0  # width of the bars

    # Plot the bars for list2 first
    plt.bar(x, list2, width, color='orange', label='viewpoint coverage')

    # Plot the bars for list1 behind list2
    plt.bar(x, list1, width, color='blue', label='added coverage')

    # Add labels and title
    plt.xlabel('viewpoint index on path')
    plt.ylabel('coverage')
    #plt.title('single viewpoint coverage')

    # Set x-axis tick labels
   

    # Add legend
    plt.legend()
    plt.gcf().set_dpi(300)
    
    # Save the plot to a TIFF file
    plt.savefig('single viewpoint coverage.tiff', format='tiff', dpi=300)
    # Display the plot
    plt.show()

plot_list(coverage_list)
plot_bar(coverage_step_list)
plot_bar2(single_viewpoint_coverage_list)
plot_dual_bar(coverage_step_list,single_viewpoint_coverage_list)
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
vis_timestep=np.asarray(vis_list).T

np.savetxt(results_path+subfolder_path+'vis_timestep.txt',vis_timestep, fmt="%d")
np.savetxt(results_path+subfolder_path+'vis_count.txt',vis_mat_count, fmt="%d")
model_path='bridge1v3.obj'

output_visualizable_faces(model_path,vis_arr,results_path+subfolder_path)

# %%
import pywavefront
model_path='bridge1v3.obj'
#Read the obj file to vertices and faces
scene = pywavefront.Wavefront(model_path, collect_faces=True)
vertices=np.array(scene.vertices)

#Read to faces
faces_list=[]
for mesh in scene.mesh_list:
    faces_list.append(mesh.faces)
faces=np.asarray(faces_list)[0]
np.savetxt('vertices.txt',vertices)
np.savetxt('faces.txt',faces,fmt="%d")

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics
#font = {'family' : 'normal',
#        'size'   : 14}

#plt.rc('font', **font)

generation=500


path='test3/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/0.1_0_0.75_0.1_0.95/' #new_list
data_list=[]
for idx in range(10):

    filepath=path+str(idx+1)+'/fitness.txt'
    data=np.loadtxt(filepath)
    
    for itemidx in range(data.shape[0]):
        if data[itemidx]>100000:
            data[itemidx]=None
    data_list.append(data)
fig, ax = plt.subplots(dpi=400)
x = np.linspace(1,data_list[0].shape[0],data_list[0].shape[0])
for idx in range(len(data_list)):
    ax.plot(x, data_list[idx], label=str(idx+1),linewidth=1)
    




# Add labels to the x and y axes
ax.set_xlabel('generation')
ax.set_ylabel('path length')

# Create the legend
labels=ax.get_label()
ax.legend()
plt.savefig('10exp.tiff', dpi=400, format='tiff')
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %% [markdown]
# output a blender file with the camera sights

# %%
import numpy as np
from scipy.spatial.transform import Rotation as R
import bpy
# Original vector (0, 0, 1) and target vector (a, b, c)
original_vector = np.array([0, 0, -1])
#target_vector = np.array([0,1, 1])  # Replace with the actual values
whole_path=np.load('test3/ruleinit=0.5_KAPPA=0.1_FOV=120_dist=10_ind=250_gen=1000/0.1_0_0.75_0.1_0.95/1/test_whole_path.npy')
#viewpoint=[np.array([0,0,0]),np.array([-5,-3,1])]
def get_euler_from_vector(target_vector,original_vector):
    # Normalize the vectors
    #target_vector[0]=-target_vector[0]
    #target_vector[1]=-target_vector[1]
    original_vector_normalized = original_vector / np.linalg.norm(original_vector)
    target_vector_normalized = target_vector / np.linalg.norm(target_vector)

    # Calculate the rotation matrix using Rodrigues' rotation formula
    rotation_axis = np.cross(original_vector_normalized, target_vector_normalized)
    rotation_axis_normalized = rotation_axis / np.linalg.norm(rotation_axis)
    rotation_angle = np.arccos(np.dot(original_vector_normalized, target_vector_normalized))
    rotation_matrix = R.from_rotvec(rotation_angle * rotation_axis_normalized)

    # Convert the rotation matrix to XYZ Euler angles (degrees)
    euler_angles_xyz = rotation_matrix.as_euler('xyz', degrees=True)
    return euler_angles_xyz

bpy.ops.object.select_all(action='SELECT')
bpy.ops.object.delete(use_global=False, confirm=False)
bpy.ops.object.select_all(action='DESELECT')
camera_idx=0

'''
camera_data = bpy.data.cameras.new('camera'+str(camera_idx))
camera_object = bpy.data.objects.new('camera'+str(camera_idx), camera_data)
bpy.context.collection.objects.link(camera_object)
camera_object.location = (viewpoint[0][0], viewpoint[0][1], viewpoint[0][2])

euler_angles_xyz=get_euler_from_vector(original_vector,viewpoint[1])
euler_angles_xyz=euler_angles_xyz/180*np.pi
camera_object.rotation_euler = ( euler_angles_xyz[0],  euler_angles_xyz[1],  euler_angles_xyz[2])
camera_data.lens = 50  # Lens length
camera_idx+=1
'''
for viewpoint in whole_path:
    camera_data = bpy.data.cameras.new('camera'+str(camera_idx))
    camera_object = bpy.data.objects.new('camera'+str(camera_idx), camera_data)
    bpy.context.collection.objects.link(camera_object)
    camera_object.location = (viewpoint[0][0], viewpoint[0][1], viewpoint[0][2])
    euler_angles_xyz=get_euler_from_vector(viewpoint[1], original_vector)
    euler_angles_xyz=euler_angles_xyz/180*np.pi
    camera_object.rotation_euler = ( euler_angles_xyz[0],  euler_angles_xyz[1],  euler_angles_xyz[2])
    camera_data.lens = 50  # Lens length
    camera_idx+=1

bpy.ops.wm.save_as_mainfile(filepath='/data/Yuxiang Zhao/PathPlanningTest/srcV10/path_and_poses.blend')
